# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    real_shape = (None, image_width, image_height, image_channels)
    real_inps = tf.placeholder(dtype=tf.float32, shape= real_shape, name="real_inputs")
    z_inps = tf.placeholder(dtype=tf.float32, shape=(None, z_dim), name="z_inputs")
    lr = tf.placeholder(dtype=tf.float32, shape=(None), name="learning_rate")

    return real_inps, z_inps, lr


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the discriminator, tensor logits of the discriminator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param images: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    # Reference: https://github.com/udacity/deep-learning/blob/master/dcgan-svhn/DCGAN.ipynb

    alpha = 0.2
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 32x32x3
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        relu1 = tf.maximum(alpha * x1, x1)
        # 16x16x64

        x2 = tf.layers.conv2d(relu1, 128, 5, strides=2, padding='same')
        bn2 = tf.layers.batch_normalization(x2, training=True)
        relu2 = tf.maximum(alpha * bn2, bn2)
        # 8x8x128

        x3 = tf.layers.conv2d(relu2, 256, 5, strides=2, padding='same')
        bn3 = tf.layers.batch_normalization(x3, training=True)
        relu3 = tf.maximum(alpha * bn3, bn3)
        # 4x4x256

        # Flatten it
        flat = tf.reshape(relu3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.sigmoid(logits)

        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variables in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    reuse = not is_train
    alpha = 0.2
    with tf.variable_scope('generator', reuse=reuse):
        # Firsh fully connected layer
        x1 = tf.layers.dense(z, 7*7*256)
        # Reshape it to start the convolutional stack
        x1 = tf.reshape(x1, (-1, 7, 7, 256))
        x1 = tf.layers.batch_normalization(x1, training=is_train)
        x1 = tf.maximum(alpha * x1, x1)
        # 7x7x256 now
        
        x2 = tf.layers.conv2d_transpose(x1, 128, 3, strides=2, padding='same')
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        x2 = tf.maximum(alpha * x2, x2)
        # 7x7x128 now
        
        x3 = tf.layers.conv2d_transpose(x2, 64, 5, strides=2, padding='same')
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        x3 = tf.maximum(alpha * x3, x3)
        # 14x14x64 now
        
        
        # Output layer
        logits = tf.layers.conv2d_transpose(x2, out_channel_dim, 5, strides=2, padding='same')
        # 28x28xout_channel_dim now
        
        out = tf.tanh(logits)
        
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    gen_model = generator(input_z, out_channel_dim)
    dis_model_real,     dis_logits_real = discriminator(input_real)
    dis_model_fake,     dis_logits_fake = discriminator(gen_model, reuse=True)
    
    dis_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=dis_logits_real, labels=tf.ones_like(dis_model_real)
        )
    )
    dis_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=dis_logits_fake, labels=tf.zeros_like(dis_model_fake)
        )
    )
    gen_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(
            logits=dis_logits_fake, labels=tf.ones_like(dis_model_fake)
        )
    )
    
    dis_loss = dis_loss_real + dis_loss_fake
    
    return dis_loss, gen_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        dis_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        gen_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
        
    
    return dis_train_opt, gen_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    n_samples, width, height, channels = data_shape
    input_real, input_z, learn_rate = model_inputs(width, height, channels, z_dim)
    dis_loss, gen_loss = model_loss(input_real, input_z, channels)
    dis_opt, gen_opt = model_opt(dis_loss, gen_loss, learn_rate, beta1)
    
    steps = 0
    show_every = 50
    print_every = 10
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1

                z_batch = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(dis_opt, feed_dict={input_real: batch_images, input_z: z_batch, learn_rate: learning_rate})
                _ = sess.run(gen_opt, feed_dict={input_real: batch_images, input_z: z_batch, learn_rate: learning_rate})

                if steps % show_every == 0:
                    n_images = 16
                    show_generator_output(sess, n_images, input_z, channels, data_image_mode)

                if steps % print_every == 0:
                    train_loss_dis = dis_loss.eval({input_z: z_batch, input_real: batch_images})
                    train_loss_gen = gen_loss.eval({input_z: z_batch})

                    print("Epoch {}/{}...".format(epoch_i, epoch_count),
                          "Discriminator Loss: {:.4f}...".format(train_loss_dis),
                          "Generator Loss: {:.4f}".format(train_loss_gen))

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0004
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 0/2... Discriminator Loss: 0.2156... Generator Loss: 2.0029
# Epoch 0/2... Discriminator Loss: 0.2138... Generator Loss: 2.0587
# Epoch 0/2... Discriminator Loss: 0.2980... Generator Loss: 1.8824
# Epoch 0/2... Discriminator Loss: 0.3861... Generator Loss: 1.6585
# Epoch 0/2... Discriminator Loss: 0.3122... Generator Loss: 2.5286
# Epoch 0/2... Discriminator Loss: 0.1999... Generator Loss: 2.7067
# Epoch 0/2... Discriminator Loss: 0.4394... Generator Loss: 4.5375
# Epoch 0/2... Discriminator Loss: 0.3683... Generator Loss: 1.7354
# Epoch 0/2... Discriminator Loss: 0.2921... Generator Loss: 1.9805
# Epoch 0/2... Discriminator Loss: 0.4109... Generator Loss: 2.4585
# Epoch 0/2... Discriminator Loss: 0.5385... Generator Loss: 1.1675
# Epoch 0/2... Discriminator Loss: 0.6284... Generator Loss: 3.8853
# Epoch 0/2... Discriminator Loss: 0.5109... Generator Loss: 1.1998
# Epoch 0/2... Discriminator Loss: 0.4958... Generator Loss: 3.6024
# Epoch 0/2... Discriminator Loss: 0.4935... Generator Loss: 1.1522
# Epoch 0/2... Discriminator Loss: 0.2502... Generator Loss: 1.9796
# Epoch 0/2... Discriminator Loss: 0.3356... Generator Loss: 3.4965
# Epoch 0/2... Discriminator Loss: 0.1848... Generator Loss: 2.3531
# Epoch 0/2... Discriminator Loss: 0.3088... Generator Loss: 1.7448
# Epoch 0/2... Discriminator Loss: 0.1637... Generator Loss: 2.8174
# Epoch 0/2... Discriminator Loss: 0.3642... Generator Loss: 1.3631
# Epoch 0/2... Discriminator Loss: 0.1518... Generator Loss: 2.4060
# Epoch 0/2... Discriminator Loss: 0.1208... Generator Loss: 2.9378
# Epoch 0/2... Discriminator Loss: 0.1110... Generator Loss: 3.1825
# Epoch 0/2... Discriminator Loss: 0.1131... Generator Loss: 2.9779
# Epoch 0/2... Discriminator Loss: 0.0773... Generator Loss: 3.4132
# Epoch 0/2... Discriminator Loss: 0.0828... Generator Loss: 3.1885
# Epoch 0/2... Discriminator Loss: 0.0795... Generator Loss: 3.2101
# Epoch 0/2... Discriminator Loss: 0.0698... Generator Loss: 3.2746
# Epoch 0/2... Discriminator Loss: 0.0778... Generator Loss: 3.3973
# Epoch 0/2... Discriminator Loss: 0.0840... Generator Loss: 3.0363
# Epoch 0/2... Discriminator Loss: 0.0928... Generator Loss: 2.9340
# Epoch 0/2... Discriminator Loss: 0.0672... Generator Loss: 3.7741
# Epoch 0/2... Discriminator Loss: 0.4047... Generator Loss: 1.5237
# Epoch 0/2... Discriminator Loss: 0.1605... Generator Loss: 2.6458
# Epoch 0/2... Discriminator Loss: 0.1532... Generator Loss: 2.8500
# Epoch 0/2... Discriminator Loss: 0.1458... Generator Loss: 2.9039
# Epoch 0/2... Discriminator Loss: 3.0516... Generator Loss: 0.0679
# Epoch 0/2... Discriminator Loss: 0.5233... Generator Loss: 1.2014
# Epoch 0/2... Discriminator Loss: 0.3646... Generator Loss: 1.4635
# Epoch 0/2... Discriminator Loss: 0.1556... Generator Loss: 2.5347
# Epoch 0/2... Discriminator Loss: 0.3291... Generator Loss: 1.5751
# Epoch 0/2... Discriminator Loss: 0.2154... Generator Loss: 2.4360
# Epoch 0/2... Discriminator Loss: 0.1426... Generator Loss: 2.9699
# Epoch 0/2... Discriminator Loss: 0.7476... Generator Loss: 0.9370
# Epoch 0/2... Discriminator Loss: 0.1767... Generator Loss: 2.9073
# Epoch 0/2... Discriminator Loss: 0.1486... Generator Loss: 2.8156
# Epoch 0/2... Discriminator Loss: 0.1315... Generator Loss: 2.9449
# Epoch 0/2... Discriminator Loss: 0.1498... Generator Loss: 2.6369
# Epoch 0/2... Discriminator Loss: 0.0925... Generator Loss: 2.9590
# Epoch 0/2... Discriminator Loss: 0.0901... Generator Loss: 3.2831
# Epoch 0/2... Discriminator Loss: 0.0807... Generator Loss: 3.1121
# Epoch 0/2... Discriminator Loss: 0.0893... Generator Loss: 3.1716
# Epoch 0/2... Discriminator Loss: 0.1113... Generator Loss: 3.1333
# Epoch 0/2... Discriminator Loss: 0.0933... Generator Loss: 3.1619
# Epoch 0/2... Discriminator Loss: 0.0941... Generator Loss: 3.1851
# Epoch 0/2... Discriminator Loss: 0.0776... Generator Loss: 3.4840
# Epoch 0/2... Discriminator Loss: 0.0953... Generator Loss: 3.7912
# Epoch 0/2... Discriminator Loss: 0.0789... Generator Loss: 3.1548
# Epoch 0/2... Discriminator Loss: 0.0751... Generator Loss: 3.4093
# Epoch 0/2... Discriminator Loss: 0.0814... Generator Loss: 3.2657
# Epoch 0/2... Discriminator Loss: 0.1009... Generator Loss: 2.9170
# Epoch 0/2... Discriminator Loss: 0.0621... Generator Loss: 4.1324
# Epoch 0/2... Discriminator Loss: 0.1442... Generator Loss: 2.4238
# Epoch 0/2... Discriminator Loss: 0.0618... Generator Loss: 3.5586
# Epoch 0/2... Discriminator Loss: 0.1362... Generator Loss: 2.5031
# Epoch 0/2... Discriminator Loss: 0.0650... Generator Loss: 3.4844
# Epoch 0/2... Discriminator Loss: 0.0837... Generator Loss: 3.0953
# Epoch 0/2... Discriminator Loss: 0.0413... Generator Loss: 4.0482
# Epoch 0/2... Discriminator Loss: 0.0603... Generator Loss: 3.5423
# Epoch 0/2... Discriminator Loss: 0.8654... Generator Loss: 6.1333
# Epoch 0/2... Discriminator Loss: 0.1029... Generator Loss: 3.2262
# Epoch 0/2... Discriminator Loss: 0.1119... Generator Loss: 3.0642
# Epoch 0/2... Discriminator Loss: 0.1140... Generator Loss: 2.9091
# Epoch 0/2... Discriminator Loss: 0.0757... Generator Loss: 3.4424
# Epoch 0/2... Discriminator Loss: 0.0724... Generator Loss: 3.5169
# Epoch 0/2... Discriminator Loss: 0.0802... Generator Loss: 3.3456
# Epoch 0/2... Discriminator Loss: 0.0709... Generator Loss: 3.6902
# Epoch 0/2... Discriminator Loss: 0.0760... Generator Loss: 3.3392
# Epoch 0/2... Discriminator Loss: 0.0546... Generator Loss: 3.7091
# Epoch 0/2... Discriminator Loss: 0.0641... Generator Loss: 3.6764
# Epoch 0/2... Discriminator Loss: 0.0540... Generator Loss: 3.9794
# Epoch 0/2... Discriminator Loss: 0.0739... Generator Loss: 3.4298
# Epoch 0/2... Discriminator Loss: 0.0671... Generator Loss: 3.8893
# Epoch 0/2... Discriminator Loss: 0.0591... Generator Loss: 3.7022
# Epoch 0/2... Discriminator Loss: 0.0627... Generator Loss: 3.8468
# Epoch 0/2... Discriminator Loss: 0.0771... Generator Loss: 3.3925
# Epoch 0/2... Discriminator Loss: 0.0507... Generator Loss: 4.0627
# Epoch 0/2... Discriminator Loss: 0.0517... Generator Loss: 4.2947
# Epoch 0/2... Discriminator Loss: 0.0465... Generator Loss: 4.0908
# Epoch 0/2... Discriminator Loss: 0.0680... Generator Loss: 3.2140
# Epoch 0/2... Discriminator Loss: 0.0504... Generator Loss: 3.8704
# Epoch 0/2... Discriminator Loss: 0.0404... Generator Loss: 4.0686
# Epoch 1/2... Discriminator Loss: 0.0541... Generator Loss: 3.9634
# Epoch 1/2... Discriminator Loss: 0.0672... Generator Loss: 3.6938
# Epoch 1/2... Discriminator Loss: 0.0572... Generator Loss: 3.8475
# Epoch 1/2... Discriminator Loss: 0.0453... Generator Loss: 4.2737
# Epoch 1/2... Discriminator Loss: 0.0359... Generator Loss: 4.1080
# Epoch 1/2... Discriminator Loss: 0.0807... Generator Loss: 3.1438
# Epoch 1/2... Discriminator Loss: 0.0425... Generator Loss: 4.3865
# Epoch 1/2... Discriminator Loss: 0.0400... Generator Loss: 4.2797
# Epoch 1/2... Discriminator Loss: 0.0424... Generator Loss: 3.8432
# Epoch 1/2... Discriminator Loss: 0.0207... Generator Loss: 4.5771
# Epoch 1/2... Discriminator Loss: 0.0380... Generator Loss: 4.2480
# Epoch 1/2... Discriminator Loss: 0.0469... Generator Loss: 3.8380
# Epoch 1/2... Discriminator Loss: 0.0425... Generator Loss: 4.0078
# Epoch 1/2... Discriminator Loss: 0.0386... Generator Loss: 4.7114
# Epoch 1/2... Discriminator Loss: 0.4266... Generator Loss: 1.7140
# Epoch 1/2... Discriminator Loss: 0.1248... Generator Loss: 2.9631
# Epoch 1/2... Discriminator Loss: 0.0852... Generator Loss: 3.4119
# Epoch 1/2... Discriminator Loss: 0.0928... Generator Loss: 3.5611
# Epoch 1/2... Discriminator Loss: 0.0885... Generator Loss: 3.3359
# Epoch 1/2... Discriminator Loss: 0.0733... Generator Loss: 3.3903
# Epoch 1/2... Discriminator Loss: 0.0811... Generator Loss: 3.1743
# Epoch 1/2... Discriminator Loss: 0.0452... Generator Loss: 3.9444
# Epoch 1/2... Discriminator Loss: 0.0457... Generator Loss: 3.7482
# Epoch 1/2... Discriminator Loss: 0.0597... Generator Loss: 3.6307
# Epoch 1/2... Discriminator Loss: 0.0460... Generator Loss: 3.8614
# Epoch 1/2... Discriminator Loss: 0.0523... Generator Loss: 3.8064
# Epoch 1/2... Discriminator Loss: 0.0339... Generator Loss: 4.4317
# Epoch 1/2... Discriminator Loss: 0.0249... Generator Loss: 4.5717
# Epoch 1/2... Discriminator Loss: 0.0546... Generator Loss: 3.6910
# Epoch 1/2... Discriminator Loss: 0.0284... Generator Loss: 4.1756
# Epoch 1/2... Discriminator Loss: 0.0446... Generator Loss: 4.0083
# Epoch 1/2... Discriminator Loss: 0.0545... Generator Loss: 3.7579
# Epoch 1/2... Discriminator Loss: 0.0399... Generator Loss: 4.0249
# Epoch 1/2... Discriminator Loss: 0.0417... Generator Loss: 4.0041
# Epoch 1/2... Discriminator Loss: 0.0332... Generator Loss: 4.1010
# Epoch 1/2... Discriminator Loss: 0.0350... Generator Loss: 4.3656
# Epoch 1/2... Discriminator Loss: 0.0228... Generator Loss: 4.5535
# Epoch 1/2... Discriminator Loss: 0.0235... Generator Loss: 4.6428
# Epoch 1/2... Discriminator Loss: 0.0290... Generator Loss: 4.1538
# Epoch 1/2... Discriminator Loss: 0.0246... Generator Loss: 4.5851
# Epoch 1/2... Discriminator Loss: 0.0368... Generator Loss: 4.0610
# Epoch 1/2... Discriminator Loss: 0.0374... Generator Loss: 4.0352
# Epoch 1/2... Discriminator Loss: 0.0279... Generator Loss: 4.3618
# Epoch 1/2... Discriminator Loss: 0.0263... Generator Loss: 4.3572
# Epoch 1/2... Discriminator Loss: 0.0338... Generator Loss: 4.0938
# Epoch 1/2... Discriminator Loss: 0.0694... Generator Loss: 3.2083
# Epoch 1/2... Discriminator Loss: 0.0203... Generator Loss: 4.8527
# Epoch 1/2... Discriminator Loss: 0.0178... Generator Loss: 5.0463
# Epoch 1/2... Discriminator Loss: 0.0342... Generator Loss: 4.0786
# Epoch 1/2... Discriminator Loss: 0.0248... Generator Loss: 4.3804
# Epoch 1/2... Discriminator Loss: 0.0302... Generator Loss: 4.0578
# Epoch 1/2... Discriminator Loss: 0.0503... Generator Loss: 3.4409
# Epoch 1/2... Discriminator Loss: 0.0280... Generator Loss: 4.2799
# Epoch 1/2... Discriminator Loss: 0.0212... Generator Loss: 4.6057
# Epoch 1/2... Discriminator Loss: 0.0333... Generator Loss: 4.1381
# Epoch 1/2... Discriminator Loss: 0.0379... Generator Loss: 3.8644
# Epoch 1/2... Discriminator Loss: 0.0333... Generator Loss: 4.1973
# Epoch 1/2... Discriminator Loss: 0.0348... Generator Loss: 3.8978
# Epoch 1/2... Discriminator Loss: 0.0240... Generator Loss: 4.5360
# Epoch 1/2... Discriminator Loss: 0.0234... Generator Loss: 5.0213
# Epoch 1/2... Discriminator Loss: 0.0199... Generator Loss: 5.2104
# Epoch 1/2... Discriminator Loss: 0.0311... Generator Loss: 4.6029
# Epoch 1/2... Discriminator Loss: 0.0212... Generator Loss: 4.5361
# Epoch 1/2... Discriminator Loss: 0.0231... Generator Loss: 4.5259
# Epoch 1/2... Discriminator Loss: 0.0191... Generator Loss: 5.2720
# Epoch 1/2... Discriminator Loss: 0.0178... Generator Loss: 5.2595
# Epoch 1/2... Discriminator Loss: 0.0206... Generator Loss: 4.6853
# Epoch 1/2... Discriminator Loss: 0.0332... Generator Loss: 4.3206
# Epoch 1/2... Discriminator Loss: 0.0194... Generator Loss: 5.0004
# Epoch 1/2... Discriminator Loss: 0.0428... Generator Loss: 3.7625
# Epoch 1/2... Discriminator Loss: 0.0227... Generator Loss: 4.6108
# Epoch 1/2... Discriminator Loss: 0.0311... Generator Loss: 4.0460
# Epoch 1/2... Discriminator Loss: 0.0220... Generator Loss: 4.5219
# Epoch 1/2... Discriminator Loss: 0.0235... Generator Loss: 4.6606
# Epoch 1/2... Discriminator Loss: 0.0249... Generator Loss: 4.5901
# Epoch 1/2... Discriminator Loss: 0.0130... Generator Loss: 5.2882
# Epoch 1/2... Discriminator Loss: 0.0269... Generator Loss: 4.4153
# Epoch 1/2... Discriminator Loss: 0.0163... Generator Loss: 4.9048
# Epoch 1/2... Discriminator Loss: 0.0156... Generator Loss: 4.8745
# Epoch 1/2... Discriminator Loss: 0.0231... Generator Loss: 4.5331
# Epoch 1/2... Discriminator Loss: 0.0159... Generator Loss: 4.7037
# Epoch 1/2... Discriminator Loss: 0.0198... Generator Loss: 4.5888
# Epoch 1/2... Discriminator Loss: 0.0400... Generator Loss: 3.9584
# Epoch 1/2... Discriminator Loss: 0.0266... Generator Loss: 4.4276
# Epoch 1/2... Discriminator Loss: 0.0486... Generator Loss: 3.6234
# Epoch 1/2... Discriminator Loss: 0.0213... Generator Loss: 4.9477
# Epoch 1/2... Discriminator Loss: 0.0248... Generator Loss: 4.3360
# Epoch 1/2... Discriminator Loss: 0.0159... Generator Loss: 4.9042
# Epoch 1/2... Discriminator Loss: 0.0195... Generator Loss: 4.6863
# Epoch 1/2... Discriminator Loss: 0.0204... Generator Loss: 4.5738
# Epoch 1/2... Discriminator Loss: 0.0210... Generator Loss: 4.6279
# Epoch 1/2... Discriminator Loss: 0.0195... Generator Loss: 4.8820
# Epoch 1/2... Discriminator Loss: 0.0238... Generator Loss: 4.4925
# Epoch 1/2... Discriminator Loss: 0.0264... Generator Loss: 4.6263

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.0004
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
